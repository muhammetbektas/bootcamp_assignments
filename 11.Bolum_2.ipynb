# %% [markdown]
# Q-1)
#
# Bir sinir ağında her biri 512 nöronlu üç katmanımız varsa, kaç parametreyi tahmin etmemiz gerekir?

# %%
tahmin=512*512+512*512+512*512
print('Bir sinir ağında her biri 512 nöronlu üç katmanımız varsa, %s parametreyi tahmin etmemiz gerekir.'%tahmin)
# Out:
# Bir sinir ağında her biri 512 nöronlu üç katmanımız varsa, 786432 parametreyi tahmin etmemiz gerekir.

# %% [markdown]
# Q-2)
#
# XOR fonksiyonu yalnızca bağımsız değişkenlerden biri doğru, diğeri yanlış olduğunda doğru değeri vermektedir.Bu işlevi tek bir tabaka (layer) kullanarak gerçekleştirmenin mümkün olduğunu düşünüyor musunuz? Yoksa birkaç birimden oluşan bir tabaka ile mi yapılabilir?

# %% [markdown]
# Bu işlemi tek bir hidden layer kullanarak gerçekleştirebiliriz.

# %% [markdown]
# Q-3) Aşağıdaki ANN'nin çıktı değerini ReLU aktivasyon fonksiyonu kullanarak hesaplayın. (y=?)
# ![image.png](attachment:image.png)

# %%
def relu(weighted):
    num=[num if num>=0 else 0 for num in weighted]
    return num

# %%
def nöron(values,weights):
    toplam=[]
    for i in range(len(weights)):
        çarp=np.dot(values,weights[i]).sum()
        toplam.append(çarp)
    return toplam

# %%
hd1=relu(nöron([4,3],[[2, 3], [1, -6]]))
hd2=relu(nöron(hd1,[[1, 3], [2, 3]]))
y=relu(nöron(hd2,[[-3,1]]))
y
# Out:
# [0]
